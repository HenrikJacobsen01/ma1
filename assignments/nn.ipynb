# %% [markdown]
# # Mandatory Assignment 1
#
# #### Part I: Multi-layer Perceptron
#
# ***
#
# Please see the description of the assignment in the README file (section 1) <br>
# **Guide notebook**: [material/nns_pytorch.ipynb](material/nns_pytorch.ipynb)
#
# Table of contents:
# 1. Activate GPU
# 2. Load data
# 3. Inspect data
# 4. Artificial neural network (**Where you will implement the ANN**)
# 5. Training hyperparameters (**Where you will add training parameters**)
# 6. Training
# 7. Plot loss and accuracy
# 8. Evaluate

# %%
# auxilary imports
import random
import matplotlib.pyplot as plt
import os
from pathlib import Path

# pytorch
import torch
import torch.nn as nn
from torchvision import transforms
import torch.nn.functional as F  # noqa

# %% [markdown]
# First, a bit of a hack in case your IDE wants to run the notebook from /`assignment/` and not the project root folder `/ma1`. We need the working directory to be `/ma1` for local imports to work.

# %%
# Ensure the working directory is set to the "ma1" folder.
while Path.cwd().name != "ma1" and "ma1" in str(Path.cwd()):
    os.chdir("..")  # Move up one directory
print(f"Working directory set to: {Path.cwd()}")
# Out:
# Working directory set to: /Users/henrikjacobsen/Desktop/CBS/Semester 2/Artifical Intelligence and Machine Learning/AIML25/Assignment/ma1

# %% [markdown]
# ##### Import local files
#
# To declutter the notebooks, your are given a module (`/src`) of useful functions. Please study each one as they contain important code (particularly `src.training` and `src.evaluation`).

# %%
# local files
from src.utils import get_device
from src.data import load_torch_data, to_dataloader, train_val_split
from src.training import fit
from src.evaluation import evaluate
from src.visualize import plot_training_history

# %% [markdown]
# ### 1. Activate GPU
# If available. Note that this is not necessary, but it will speed up your training.

# %%
# Device will determine whether to run the training on GPU or CPU.
DEVICE = get_device()
# Out:
# Running pytorch version (2.5.1) with backend = cpu

# %% [markdown]
# ### 2. Load data

# %%
# load the training/validation data
train_val = load_torch_data(
    dataset="MNIST",
    root = 'data',                     # The root directory where the dataset will be stored
    download = True,                   # If the dataset is not found at root, it will be downloaded
    train = True,                      # The train dataset (as opposed to the test dataset)
    transform = transforms.ToTensor()  # transformations to be applied to the dataset (only cast to tensor)
)

# load the testing data
test = load_torch_data(
    dataset = "MNIST",
    root = 'data',
    download = True,
    train = False,
    transform = transforms.ToTensor()
)

f"{len(train_val)=}, {len(test)=}"
# Out:
# 'len(train_val)=60000, len(test)=10000'

# %%
# split training data in training and validation (just like train_test_split in sklearn)
train, val = train_val_split(train_val, val_ratio=0.2, seed=42)

f"{len(val)=}, {len(train)=}"
# Out:
# 'len(val)=12000, len(train)=48000'

# %%
# create dataloders for easy batch loading during training
train_loader = to_dataloader(train, batch_size = 64, shuffle = True)
val_loader = to_dataloader(val, batch_size = 64, shuffle = False)
test_loader = to_dataloader(test, batch_size = 64, shuffle = False)

# %% [markdown]
# ### 3. Inspect data

# %%
# Pick a random example from the training set
selection = random.randrange(len(train)-1)
image, label = train[selection]

# Plot the image
print(f"Default image shape: {image.shape}")
image = image.view([28,28])

print(f"Reshaped image shape: {image.shape}")
plt.imshow(image, cmap="gray")

print(f"Total pixels: {image.shape[0] * image.shape[1]}")

# Print the label
print(f"The label for this image: {label}")
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# Total pixels: 784
# The label for this image: 1

# %% [markdown]
# ***
#
# ### 4. Artificial neural network

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        
        # Define layers
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)
    
    def forward(self, x: torch.Tensor):
        # Define forward pass
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ### 5. Training hyperparameters

# %%
LR = 0.001  # TODO: define the learning rate
NUM_EPOCHS = 20 # TODO: define the number of epochs (i.e. passes over the dataset)
criterion = nn.CrossEntropyLoss()  # The loss function

# %% [markdown]
# Instantiate the model and optimizer

# %%
model = MLP().to(DEVICE)   # Create an instance of the MLP model and move it to device (GPU or CPU)
optimizer = torch.optim.SGD(model.parameters(), lr=LR) # The optimizer (here, SGD - you can also try ADAM)

# %%
model
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ### 6. Training

# %%
model, history = fit(
    model,
    train_loader = train_loader,
    val_loader = val_loader,
    device = DEVICE,
    optimizer = optimizer,
    criterion = criterion,
    num_epochs = NUM_EPOCHS
)
# Out:
# Epoch [1/20]: Train Loss: 2.2893 | Train Accuracy: 10.86% | Val Loss: 2.2739 | Val Accuracy: 13.59%
# Epoch [2/20]: Train Loss: 2.2563 | Train Accuracy: 17.70% | Val Loss: 2.2360 | Val Accuracy: 22.22%
# Epoch [3/20]: Train Loss: 2.2111 | Train Accuracy: 31.45% | Val Loss: 2.1821 | Val Accuracy: 40.03%
# Epoch [4/20]: Train Loss: 2.1450 | Train Accuracy: 45.26% | Val Loss: 2.1010 | Val Accuracy: 49.86%
# Epoch [5/20]: Train Loss: 2.0438 | Train Accuracy: 52.42% | Val Loss: 1.9782 | Val Accuracy: 55.18%
# Epoch [6/20]: Train Loss: 1.8958 | Train Accuracy: 57.31% | Val Loss: 1.8056 | Val Accuracy: 60.36%
# Epoch [7/20]: Train Loss: 1.6996 | Train Accuracy: 62.56% | Val Loss: 1.5912 | Val Accuracy: 64.84%
# Epoch [8/20]: Train Loss: 1.4738 | Train Accuracy: 67.96% | Val Loss: 1.3639 | Val Accuracy: 70.49%
# Epoch [9/20]: Train Loss: 1.2535 | Train Accuracy: 73.83% | Val Loss: 1.1593 | Val Accuracy: 76.45%
# Epoch [10/20]: Train Loss: 1.0670 | Train Accuracy: 78.16% | Val Loss: 0.9950 | Val Accuracy: 79.40%
# Epoch [11/20]: Train Loss: 0.9216 | Train Accuracy: 80.44% | Val Loss: 0.8695 | Val Accuracy: 81.22%
# Epoch [12/20]: Train Loss: 0.8118 | Train Accuracy: 81.94% | Val Loss: 0.7756 | Val Accuracy: 82.59%
# Epoch [13/20]: Train Loss: 0.7293 | Train Accuracy: 82.99% | Val Loss: 0.7049 | Val Accuracy: 83.18%
# Epoch [14/20]: Train Loss: 0.6666 | Train Accuracy: 83.87% | Val Loss: 0.6503 | Val Accuracy: 83.88%
# Epoch [15/20]: Train Loss: 0.6183 | Train Accuracy: 84.53% | Val Loss: 0.6080 | Val Accuracy: 84.51%
# Epoch [16/20]: Train Loss: 0.5802 | Train Accuracy: 85.20% | Val Loss: 0.5747 | Val Accuracy: 84.88%
# Epoch [17/20]: Train Loss: 0.5497 | Train Accuracy: 85.71% | Val Loss: 0.5482 | Val Accuracy: 85.41%
# Epoch [18/20]: Train Loss: 0.5247 | Train Accuracy: 86.18% | Val Loss: 0.5256 | Val Accuracy: 85.97%
# Epoch [19/20]: Train Loss: 0.5039 | Train Accuracy: 86.53% | Val Loss: 0.5071 | Val Accuracy: 86.21%
# Epoch [20/20]: Train Loss: 0.4864 | Train Accuracy: 86.83% | Val Loss: 0.4915 | Val Accuracy: 86.53%

# %% [markdown]
# ### 7. Plot loss and accuracy

# %%
plot_training_history(history)

# %% [markdown]
# ### 8. Evaluate

# %%
evaluate(
    model = model,
    data_loader = train_loader,  # evaluate on training data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.4781, Accuracy: 87.03%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94      4735
#            1       0.91      0.97      0.94      5383
#            2       0.86      0.83      0.85      4762
#            3       0.86      0.83      0.85      4886
#            4       0.87      0.88      0.87      4681
#            5       0.84      0.76      0.80      4368
#            6       0.89      0.92      0.91      4752
#            7       0.91      0.88      0.89      4983
#            8       0.81      0.83      0.82      4674
#            9       0.80      0.83      0.82      4776
#
#     accuracy                           0.87     48000
#    macro avg       0.87      0.87      0.87     48000
# weighted avg       0.87      0.87      0.87     48000

# %%
evaluate(
    model = model,
    data_loader = val_loader,  # evaluate on validation data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.4915, Accuracy: 86.53%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1188
#            1       0.91      0.96      0.94      1359
#            2       0.86      0.81      0.83      1196
#            3       0.85      0.84      0.85      1245
#            4       0.85      0.88      0.87      1161
#            5       0.82      0.79      0.80      1053
#            6       0.89      0.91      0.90      1166
#            7       0.90      0.87      0.88      1282
#            8       0.84      0.85      0.84      1177
#            9       0.78      0.79      0.79      1173
#
#     accuracy                           0.87     12000
#    macro avg       0.86      0.86      0.86     12000
# weighted avg       0.86      0.87      0.86     12000

# %%
evaluate(
    model = model,
    data_loader = test_loader,  # evaluate on testing data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.4617, Accuracy: 87.26%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       980
#            1       0.94      0.97      0.96      1135
#            2       0.89      0.84      0.86      1032
#            3       0.86      0.86      0.86      1010
#            4       0.84      0.89      0.86       982
#            5       0.83      0.75      0.79       892
#            6       0.89      0.91      0.90       958
#            7       0.91      0.87      0.89      1028
#            8       0.82      0.84      0.83       974
#            9       0.82      0.81      0.81      1009
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
